# %% [markdown]
# <a href="https://colab.research.google.com/github/demobaba007/DSE/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %% [markdown]
# Creating dataframes

# %%
data = [['John', 25, 'New York'],
        ['Peter', 30, 'Chicago'],
        ['Maria', 35, 'Dublin'],
        ['Alice', 40, 'Rome']]

# %%
data
# Out:
# [['John', 25, 'New York'],
#  ['Peter', 30, 'Chicago'],
#  ['Maria', 35, 'Dublin'],
#  ['Alice', 40, 'Rome']]

# %%
type(data)
# Out:
# list

# %%
columns = ['Name', 'Age', 'City']

# %%
df = pd.DataFrame(data, columns = columns)
df
# Out:
#     Name  Age      City
# 0   John   25  New York
# 1  Peter   30   Chicago
# 2  Maria   35    Dublin
# 3  Alice   40      Rome

# %%
data = {'Name': ['John', 'Peter', 'Maria', 'Alice'],
        'Age': [25, 30, 35, 40],
        'City': ['Chicago', 'Dublin', 'New York', 'Rome']}

# %%
data
# Out:
# {'Name': ['John', 'Peter', 'Maria', 'Alice'],
#  'Age': [25, 30, 35, 40],
#  'City': ['Chicago', 'Dublin', 'New York', 'Rome']}

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City
# 0   John   25   Chicago
# 1  Peter   30    Dublin
# 2  Maria   35  New York
# 3  Alice   40      Rome

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f6a02610-6446-4b51-a05c-192b3a366613" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6a02610-6446-4b51-a05c-192b3a366613">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv("/content/student1.csv")

# %%
dataset
# Out:
#    Roll Number    Name  Maths  Hindi    CS Section
# 0         1234   Abhay   68.0     60  90.0       A
# 1         1354   Kirti   78.0     65  57.0       B
# 2         1455    Diya   89.0     54  69.0       A
# 3         1897  Rihaan   78.0     56  78.0       A
# 4         1989  Jiyaan   78.0     56  45.0       B
# 5         2232     Amy   67.0     96  26.0       B
# 6         6745    Ross   87.0     56  78.0       A
# 7         1455    Diya   89.0     54  69.0       A
# 8         1989  Jiyaan   78.0     56   NaN     NaN
# 9         2232     Amy    NaN     96   NaN       B

# %%
dataset.head()
# Out:
#    Roll Number    Name  Maths  Hindi    CS Section
# 0         1234   Abhay   68.0     60  90.0       A
# 1         1354   Kirti   78.0     65  57.0       B
# 2         1455    Diya   89.0     54  69.0       A
# 3         1897  Rihaan   78.0     56  78.0       A
# 4         1989  Jiyaan   78.0     56  45.0       B

# %%
dataset.head(4)
# Out:
#    Roll Number    Name  Maths  Hindi    CS Section
# 0         1234   Abhay   68.0     60  90.0       A
# 1         1354   Kirti   78.0     65  57.0       B
# 2         1455    Diya   89.0     54  69.0       A
# 3         1897  Rihaan   78.0     56  78.0       A

# %%
dataset.tail()
# Out:
#    Roll Number    Name  Maths  Hindi    CS Section
# 5         2232     Amy   67.0     96  26.0       B
# 6         6745    Ross   87.0     56  78.0       A
# 7         1455    Diya   89.0     54  69.0       A
# 8         1989  Jiyaan   78.0     56   NaN     NaN
# 9         2232     Amy    NaN     96   NaN       B

# %%
dataset.tail(3)
# Out:
#    Roll Number    Name  Maths  Hindi    CS Section
# 7         1455    Diya   89.0     54  69.0       A
# 8         1989  Jiyaan   78.0     56   NaN     NaN
# 9         2232     Amy    NaN     96   NaN       B

# %%
dataset.shape
# Out:
# (10, 6)

# %%
dataset.size
# Out:
# 60

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
dataset.dtypes
# Out:
# Roll Number      int64
# Name            object
# Maths          float64
# Hindi            int64
# CS             float64
# Section         object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Roll Number  10 non-null     int64
#  1   Name         10 non-null     object
#  2   Maths        9 non-null      float64
#  3   Hindi        10 non-null     int64
#  4   CS           8 non-null      float64
#  5   Section      9 non-null      object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 612.0+ bytes

# %%
dataset.describe()
# Out:
#        Roll Number      Maths      Hindi         CS
# count    10.000000   9.000000  10.000000   8.000000
# mean   2258.200000  79.111111  64.900000  64.000000
# std    1618.125582   8.161563  16.709611  20.605131
# min    1234.000000  67.000000  54.000000  26.000000
# 25%    1455.000000  78.000000  56.000000  54.000000
# 50%    1943.000000  78.000000  56.000000  69.000000
# 75%    2171.250000  87.000000  63.750000  78.000000
# max    6745.000000  89.000000  96.000000  90.000000

# %% [markdown]
# Accessing elements using loc and iloc

# %%
dataset['Maths']
# Out:
# 0    68.0
# 1    78.0
# 2    89.0
# 3    78.0
# 4    78.0
# 5    67.0
# 6    87.0
# 7    89.0
# 8    78.0
# 9     NaN
# Name: Maths, dtype: float64

# %%
type(dataset["Maths"])
# Out:
# pandas.core.series.Series

# %%
dataset.Maths
# Out:
# 0    68.0
# 1    78.0
# 2    89.0
# 3    78.0
# 4    78.0
# 5    67.0
# 6    87.0
# 7    89.0
# 8    78.0
# 9     NaN
# Name: Maths, dtype: float64

# %%
dataset.Maths.mean()
# Out:
# np.float64(79.11111111111111)

# %%
dataset.Maths.iloc[0:4]
# Out:
# 0    68.0
# 1    78.0
# 2    89.0
# 3    78.0
# Name: Maths, dtype: float64

# %%
dataset[['Maths', 'CS']]
# Out:
#    Maths    CS
# 0   68.0  90.0
# 1   78.0  57.0
# 2   89.0  69.0
# 3   78.0  78.0
# 4   78.0  45.0
# 5   67.0  26.0
# 6   87.0  78.0
# 7   89.0  69.0
# 8   78.0   NaN
# 9    NaN   NaN

# %%
dataset.iloc[0:4, 0:4]
# Out:
#    Roll Number    Name  Maths  Hindi
# 0         1234   Abhay   68.0     60
# 1         1354   Kirti   78.0     65
# 2         1455    Diya   89.0     54
# 3         1897  Rihaan   78.0     56

# %%
dataset.iloc[0:4, :]
# Out:
#    Roll Number    Name  Maths  Hindi    CS Section
# 0         1234   Abhay   68.0     60  90.0       A
# 1         1354   Kirti   78.0     65  57.0       B
# 2         1455    Diya   89.0     54  69.0       A
# 3         1897  Rihaan   78.0     56  78.0       A

# %%
dataset.iloc[0:4, [0, 3, 5]]
# Out:
#    Roll Number  Hindi Section
# 0         1234     60       A
# 1         1354     65       B
# 2         1455     54       A
# 3         1897     56       A

# %%
dataset.iloc[:, 0:4]
# Out:
#    Roll Number    Name  Maths  Hindi
# 0         1234   Abhay   68.0     60
# 1         1354   Kirti   78.0     65
# 2         1455    Diya   89.0     54
# 3         1897  Rihaan   78.0     56
# 4         1989  Jiyaan   78.0     56
# 5         2232     Amy   67.0     96
# 6         6745    Ross   87.0     56
# 7         1455    Diya   89.0     54
# 8         1989  Jiyaan   78.0     56
# 9         2232     Amy    NaN     96

# %%
dataset.loc[:, "CS"]
# Out:
# 0    90.0
# 1    57.0
# 2    69.0
# 3    78.0
# 4    45.0
# 5    26.0
# 6    78.0
# 7    69.0
# 8     NaN
# 9     NaN
# Name: CS, dtype: float64

# %%
dataset.loc[0:3, "Maths":"CS"]
# Out:
#    Maths  Hindi    CS
# 0   68.0     60  90.0
# 1   78.0     65  57.0
# 2   89.0     54  69.0
# 3   78.0     56  78.0

# %%
dataset.loc[0:6]
# Out:
#    Roll Number    Name  Maths  Hindi    CS Section
# 0         1234   Abhay   68.0     60  90.0       A
# 1         1354   Kirti   78.0     65  57.0       B
# 2         1455    Diya   89.0     54  69.0       A
# 3         1897  Rihaan   78.0     56  78.0       A
# 4         1989  Jiyaan   78.0     56  45.0       B
# 5         2232     Amy   67.0     96  26.0       B
# 6         6745    Ross   87.0     56  78.0       A

# %% [markdown]
# Deleting rows and columns

# %%
dataset1 = dataset.drop("Maths", axis = 1)

# %%
dataset1
# Out:
#    Roll Number    Name  Hindi    CS Section
# 0         1234   Abhay     60  90.0       A
# 1         1354   Kirti     65  57.0       B
# 2         1455    Diya     54  69.0       A
# 3         1897  Rihaan     56  78.0       A
# 4         1989  Jiyaan     56  45.0       B
# 5         2232     Amy     96  26.0       B
# 6         6745    Ross     56  78.0       A
# 7         1455    Diya     54  69.0       A
# 8         1989  Jiyaan     56   NaN     NaN
# 9         2232     Amy     96   NaN       B

# %%
dataset.drop("Hindi", axis = 1, inplace = True)

# %%
dataset
# Out:
#    Roll Number    Name  Maths    CS Section
# 0         1234   Abhay   68.0  90.0       A
# 1         1354   Kirti   78.0  57.0       B
# 2         1455    Diya   89.0  69.0       A
# 3         1897  Rihaan   78.0  78.0       A
# 4         1989  Jiyaan   78.0  45.0       B
# 5         2232     Amy   67.0  26.0       B
# 6         6745    Ross   87.0  78.0       A
# 7         1455    Diya   89.0  69.0       A
# 8         1989  Jiyaan   78.0   NaN     NaN
# 9         2232     Amy    NaN   NaN       B

# %%
dataset.columns
# Out:
# Index(['Roll Number', 'Name', 'Maths', 'CS', 'Section'], dtype='object')

# %%
dataset.drop([0], axis = 0)
# Out:
#    Roll Number    Name  Maths    CS Section
# 1         1354   Kirti   78.0  57.0       B
# 2         1455    Diya   89.0  69.0       A
# 3         1897  Rihaan   78.0  78.0       A
# 4         1989  Jiyaan   78.0  45.0       B
# 5         2232     Amy   67.0  26.0       B
# 6         6745    Ross   87.0  78.0       A
# 7         1455    Diya   89.0  69.0       A
# 8         1989  Jiyaan   78.0   NaN     NaN
# 9         2232     Amy    NaN   NaN       B

# %%
dataset
# Out:
#    Roll Number    Name  Maths    CS Section
# 0         1234   Abhay   68.0  90.0       A
# 1         1354   Kirti   78.0  57.0       B
# 2         1455    Diya   89.0  69.0       A
# 3         1897  Rihaan   78.0  78.0       A
# 4         1989  Jiyaan   78.0  45.0       B
# 5         2232     Amy   67.0  26.0       B
# 6         6745    Ross   87.0  78.0       A
# 7         1455    Diya   89.0  69.0       A
# 8         1989  Jiyaan   78.0   NaN     NaN
# 9         2232     Amy    NaN   NaN       B

# %%
dataset.reset_index()
# Out:
#    index  Roll Number    Name  Maths    CS Section
# 0      0         1234   Abhay   68.0  90.0       A
# 1      1         1354   Kirti   78.0  57.0       B
# 2      2         1455    Diya   89.0  69.0       A
# 3      3         1897  Rihaan   78.0  78.0       A
# 4      4         1989  Jiyaan   78.0  45.0       B
# 5      5         2232     Amy   67.0  26.0       B
# 6      6         6745    Ross   87.0  78.0       A
# 7      7         1455    Diya   89.0  69.0       A
# 8      8         1989  Jiyaan   78.0   NaN     NaN
# 9      9         2232     Amy    NaN   NaN       B

# %%
dataset
# Out:
#    Roll Number    Name  Maths    CS Section
# 0         1234   Abhay   68.0  90.0       A
# 1         1354   Kirti   78.0  57.0       B
# 2         1455    Diya   89.0  69.0       A
# 3         1897  Rihaan   78.0  78.0       A
# 4         1989  Jiyaan   78.0  45.0       B
# 5         2232     Amy   67.0  26.0       B
# 6         6745    Ross   87.0  78.0       A
# 7         1455    Diya   89.0  69.0       A
# 8         1989  Jiyaan   78.0   NaN     NaN
# 9         2232     Amy    NaN   NaN       B

# %%
dataset.head()
# Out:
#    Roll Number    Name  Maths    CS Section
# 0         1234   Abhay   68.0  90.0       A
# 1         1354   Kirti   78.0  57.0       B
# 2         1455    Diya   89.0  69.0       A
# 3         1897  Rihaan   78.0  78.0       A
# 4         1989  Jiyaan   78.0  45.0       B

# %%
df = pd.read_csv("/content/student1.csv")

# %%
df
# Out:
#    Roll Number    Name  Maths  Hindi    CS Section
# 0         1234   Abhay   68.0     60  90.0       A
# 1         1354   Kirti   78.0     65  57.0       B
# 2         1455    Diya   89.0     54  69.0       A
# 3         1897  Rihaan   78.0     56  78.0       A
# 4         1989  Jiyaan   78.0     56  45.0       B
# 5         2232     Amy   67.0     96  26.0       B
# 6         6745    Ross   87.0     56  78.0       A
# 7         1455    Diya   89.0     54  69.0       A
# 8         1989  Jiyaan   78.0     56   NaN     NaN
# 9         2232     Amy    NaN     96   NaN       B
